# %%
import os
import folium
import json
from folium.features import CustomIcon
from folium.plugins import FloatImage
from folium.plugins import MousePosition

# %%
flood_CFS=os.path.join('/Users/fengyanshi15/work/NTHMP/Flood/VB_5','CFS_flood.png')
flood_LIS=os.path.join('/Users/fengyanshi15/work/NTHMP/Flood/VB_5','LIS_flood.png')
flood_PR=os.path.join('/Users/fengyanshi15/work/NTHMP/Flood/VB_5','PR_flood.png')
flood_CVV80=os.path.join('/Users/fengyanshi15/work/NTHMP/Flood/VB_5','CVV80_flood.png')
flood_COMB=os.path.join('/Users/fengyanshi15/work/NTHMP/Flood/VB_5','COMB_flood.png')
#fld_bar=os.path.join('/Users/fengyanshi15/work/NTHMP/colorbar','Colorbar_0_1.png')

m=folium.Map([37.3612,-76.3895],zoom_start=11.2,control_scale=True)
img1=folium.raster_layers.ImageOverlay(
    name='flood_CFS',
    image=flood_CFS,
#     bounds=[[36.461,-76.211],[36.660722,-75.811278]],
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    opacity=0.7,
    interactive=True,
    cross_origin=False,
    zindex=1,
    show=False,
)
img1.add_to(m)

img2=folium.raster_layers.ImageOverlay(
    name='flood_LIS',
    image=flood_LIS,
#     bounds=[[36.461,-76.211],[36.660722,-75.811278]],
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    opacity=0.7,
    interactive=True,
    cross_origin=False,
    zindex=1,
    show=False,
)

img2.add_to(m)

img3=folium.raster_layers.ImageOverlay(
    name='flood_PR',
    image=flood_PR,
#     bounds=[[36.461,-76.211],[36.660722,-75.811278]],
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    opacity=0.7,
    interactive=True,
    cross_origin=False,
    zindex=1,
    show=False,
)

img3.add_to(m)

img4=folium.raster_layers.ImageOverlay(
    name='flood_CVV80',
    image=flood_CVV80,
#     bounds=[[36.461,-76.211],[36.660722,-75.811278]],
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    opacity=0.7,
    interactive=True,
    cross_origin=False,
    zindex=1,
    show=False,
)

img4.add_to(m)

img5=folium.raster_layers.ImageOverlay(
    name='flood_COMB',
    image=flood_COMB,
#     bounds=[[36.461,-76.211],[36.660722,-75.811278]],
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    opacity=0.7,
    interactive=True,
    cross_origin=False,
    zindex=1,
    show=True,
)

img5.add_to(m)

#fld_icon=CustomIcon(
#     fld_bar,
#     icon_size=(80,250),
#     icon_anchor=(40,125)
# )
#fld_marker=folium.Marker(
#     location=[36.5609,-75.811278],
#     icon=fld_icon
# )
#m.add_child(fld_marker)

#FloatImage(fld_bar,bottom=0,left=0).add_to(m)

folium.LayerControl().add_to(m)

kw = {
    'color': 'yellow',
    'line_cap': 'round',
    'fill': True,
   'fill_color': 'none',
    'weight': 2.5,
   'popup': 'Flooding Simulation area',
   'tooltip': '<strong>Click me!</strong>',
}

folium.Rectangle(
    bounds=[[37.228,-76.556],[37.494389,-76.222944]],
    line_join='round',
    dash_array='5, 5',
    **kw,
).add_to(m)

formatter = "function(num) {return L.Util.formatNum(num, 5) + ' º ';};"

MousePosition(
    position='topright',
    separator=' ,  ',
    empty_string='NaN',
    lng_first=True,
    num_digits=20,
    prefix='Coordinates:',
    lat_formatter=formatter,
    lng_formatter=formatter
).add_to(m)

m.save(os.path.join('../maps', 'Flood_V5.html'))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
